# %%
import gdown

# %%
url = "https://drive.google.com/file/d/1z0mreUtRmR-P-magILsDR3T7M6IkGXtY/view?usp=sharing"

# %%
file_id = url.split("/")[-2]

# %%
prefix = "https://drive.google.com/uc?/export=download&id="
gdown.download(prefix+file_id, "Chest-CT-Scan-data.zip")
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?/export=download&id=1z0mreUtRmR-P-magILsDR3T7M6IkGXtY
# From (redirected): https://drive.google.com/uc?%2Fexport=download&id=1z0mreUtRmR-P-magILsDR3T7M6IkGXtY&confirm=t&uuid=41bd7efe-440f-4851-9f30-deab2aec728e
# To: c:\Users\soham\OneDrive\Desktop\chestDiseaseIdentification\research\Chest-CT-Scan-data.zip
# 100%|██████████| 49.0M/49.0M [08:51<00:00, 92.1kB/s]
# 'Chest-CT-Scan-data.zip'

# %%
import os
os.getcwd()
# Out:
# 'c:\\Users\\soham\\OneDrive\\Desktop\\chestDiseaseIdentification\\research'

# %%
os.chdir("../")

# %%
os.getcwd()
# Out:
# 'c:\\Users\\soham\\OneDrive\\Desktop\\chestDiseaseIdentification'
